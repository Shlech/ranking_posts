# %% [markdown]
# ### Подключение к базе и таблицы с юзерами и постами

# %%
# !pip3 install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 26.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9

# %%
from sqlalchemy import create_engine


engine = create_engine("postgresql://robot-startml-ro:pheiph0hahj1Vaif@postgres.lab.karpov.courses:6432/startml")

connection = engine.connect().execution_options(stream_results=True)

# %%
### Посты и топики
### Сгенерируем эмбеддинги постов
import pandas as pd


posts_info = pd.read_sql(
    """SELECT * FROM public.post_text_df""",
    con=connection
)

posts_info
# Out:
#       post_id                                               text     topic
# 0           1  UK economy facing major risks\n\nThe UK manufa...  business
# 1           2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2           3  Asian quake hits European shares\n\nShares in ...  business
# 3           4  India power shares jump on debut\n\nShares in ...  business
# 4           5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...       ...                                                ...       ...
# 7018     7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019     7316  I give this movie 2 stars purely because of it...     movie
# 7020     7317  I cant believe this film was allowed to be mad...     movie
# 7021     7318  The version I saw of this film was the Blockbu...     movie
# 7022     7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
# [7023 rows x 3 columns]

# %%
### Сделаем эмбеддинги постов

from transformers import AutoTokenizer
from transformers import BertModel  # https://huggingface.co/docs/transformers/model_doc/bert#transformers.BertModel
from transformers import RobertaModel  # https://huggingface.co/docs/transformers/model_doc/roberta#transformers.RobertaModel
from transformers import DistilBertModel  # https://huggingface.co/docs/transformers/model_doc/distilbert#transformers.DistilBertModel


def get_model(model_name):
    assert model_name in ['bert', 'roberta', 'distilbert']

    checkpoint_names = {
        'bert': 'bert-base-cased',  # https://huggingface.co/bert-base-cased
        'roberta': 'roberta-base',  # https://huggingface.co/roberta-base
        'distilbert': 'distilbert-base-cased'  # https://huggingface.co/distilbert-base-cased
    }

    model_classes = {
        'bert': BertModel,
        'roberta': RobertaModel,
        'distilbert': DistilBertModel
    }

    return AutoTokenizer.from_pretrained(checkpoint_names[model_name]), model_classes[model_name].from_pretrained(checkpoint_names[model_name])

# %%
tokenizer, model = get_model('distilbert')

# %%
### Сделаем датасет для постов

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from transformers import DataCollatorWithPadding


class PostDataset(Dataset):
    def __init__(self, texts, tokenizer):
        super().__init__()

        self.texts = tokenizer.batch_encode_plus(
            texts,
            add_special_tokens=True,
            return_token_type_ids=False,
            return_tensors='pt',
            truncation=True,
            padding=True
        )
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        return {'input_ids': self.texts['input_ids'][idx], 'attention_mask': self.texts['attention_mask'][idx]}

    def __len__(self):
        return len(self.texts['input_ids'])
    
    
dataset = PostDataset(posts_info['text'].values.tolist(), tokenizer)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

loader = DataLoader(dataset, batch_size=32, collate_fn=data_collator, pin_memory=True, shuffle=False)

# %%
import torch
from tqdm import tqdm


@torch.inference_mode()
def get_embeddings_labels(model, loader):
    model.eval()
    
    total_embeddings = []
    
    for batch in tqdm(loader):
        batch = {key: batch[key].to(device) for key in ['attention_mask', 'input_ids']}

        embeddings = model(**batch)['last_hidden_state'][:, 0, :]

        total_embeddings.append(embeddings.cpu())

    return torch.cat(total_embeddings, dim=0)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)
print(torch.cuda.get_device_name())

model = model.to(device)
# Out:
# cuda:0
# Tesla P100-PCIE-16GB

# %%
embeddings = get_embeddings_labels(model, loader).numpy()

embeddings
# Out:
# 100%|██████████| 220/220 [01:03<00:00,  3.45it/s]
# array([[ 3.63150656e-01,  4.89375181e-02, -2.64081180e-01, ...,
#         -1.41593263e-01,  1.59181021e-02,  9.18256337e-05],
#        [ 2.36416280e-01, -1.59500659e-01, -3.27798188e-01, ...,
#         -2.89936393e-01,  1.19365379e-01, -1.62326719e-03],
#        [ 3.75191480e-01, -1.13944046e-01, -2.40546837e-01, ...,
#         -3.38919461e-01,  5.86941987e-02, -2.12655552e-02],
#        ...,
#        [ 3.40382725e-01,  6.64921924e-02, -1.63184285e-01, ...,
#         -8.65627527e-02,  2.03403741e-01,  3.20905708e-02],
#        [ 4.32092190e-01,  1.10915322e-02, -1.17306069e-01, ...,
#          7.54015595e-02,  1.02739751e-01,  1.52742220e-02],
#        [ 3.04277658e-01, -7.62156695e-02, -6.77587390e-02, ...,
#         -5.43489158e-02,  2.44383484e-01, -1.41485883e-02]], dtype=float32)

# %%
### Попробуем кластеризовать тексты

from sklearn.decomposition import PCA

centered = embeddings - embeddings.mean()

pca = PCA(n_components=50)
pca_decomp = pca.fit_transform(centered)

# %%
from sklearn.cluster import KMeans

n_clusters = 15

kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(pca_decomp)

posts_info['TextCluster'] = kmeans.labels_

dists_columns = [f'DistanceToCluster_{i}' for i in range(n_clusters)]

dists_df = pd.DataFrame(
    data=kmeans.transform(pca_decomp),
    columns=dists_columns
)

dists_df.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    DistanceToCluster_0  DistanceToCluster_1  DistanceToCluster_2  \
# 0             3.463388             3.003918             3.411459
# 1             3.136657             2.850912             3.218539
# 2             3.131488             3.038105             3.287994
# 3             3.792933             3.278644             3.696762
# 4             2.785611             2.651160             2.853061
#
#    DistanceToCluster_3  DistanceToCluster_4  DistanceToCluster_5  \
# 0             2.216097             2.360039             3.408452
# 1             2.235173             2.324111             3.327500
# 2             3.033720             2.397022             3.358129
# 3             3.392768             2.815933             3.739773
# 4             2.936968             2.046933             2.816801
#
#    DistanceToCluster_6  DistanceToCluster_7  DistanceToCluster_8  \
# 0             3.621365             3.469159             3.385468
# 1             3.358584             3.245137             3.367481
# 2             3.364051             3.393217             3.496757
# 3             3.796273             4.062542             3.749640
# 4             3.056302             3.243731             2.807291
#
#    DistanceToCluster_9  DistanceToCluster_10  DistanceToCluster_11  \
# 0             3.372909              1.816690              2.832223
# 1             3.325905              1.412822              2.551059
# 2             3.267370              1.711374              2.882332
# 3             3.513695              2.460979              3.374777
# 4             3.041460              2.135139              2.148691
#
#    DistanceToCluster_12  DistanceToCluster_13  DistanceToCluster_14
# 0              3.440214              1.947251              3.663139
# 1              2.976881              2.198815              3.466526
# 2              2.967289              1.818425              3.449917
# 3              3.714448              2.436172              3.156982
# 4              2.646893              1.471153              3.167368

# %%
posts_info = pd.concat((posts_info, dists_df), axis=1)

posts_info.drop(["text"], axis=1, inplace=True)

posts_info
# Out:
#       post_id     topic  TextCluster  DistanceToCluster_0  \
# 0           1  business           10             3.463388
# 1           2  business           10             3.136657
# 2           3  business           10             3.131488
# 3           4  business           13             3.792933
# 4           5  business           13             2.785611
# ...       ...       ...          ...                  ...
# 7018     7315     movie            5             1.821625
# 7019     7316     movie            5             1.842541
# 7020     7317     movie            5             1.995335
# 7021     7318     movie            8             1.532328
# 7022     7319     movie            0             1.768652
#
#       DistanceToCluster_1  DistanceToCluster_2  DistanceToCluster_3  \
# 0                3.003918             3.411459             2.216097
# 1                2.850912             3.218539             2.235173
# 2                3.038105             3.287994             3.033720
# 3                3.278644             3.696762             3.392768
# 4                2.651160             2.853061             2.936968
# ...                   ...                  ...                  ...
# 7018             2.796970             2.023037             3.352438
# 7019             2.484546             1.798031             3.188043
# 7020             2.505481             2.190827             3.403204
# 7021             3.087979             1.858544             3.441778
# 7022             2.957340             2.114759             3.561759
#
#       DistanceToCluster_4  DistanceToCluster_5  DistanceToCluster_6  \
# 0                2.360039             3.408452             3.621365
# 1                2.324111             3.327500             3.358584
# 2                2.397022             3.358129             3.364051
# 3                2.815933             3.739773             3.796273
# 4                2.046933             2.816801             3.056302
# ...                   ...                  ...                  ...
# 7018             2.743425             1.278430             2.962159
# 7019             2.453938             0.928041             2.609681
# 7020             2.818579             1.505148             2.397477
# 7021             2.996449             1.488639             3.317243
# 7022             2.910630             2.159946             3.044435
#
#       DistanceToCluster_7  DistanceToCluster_8  DistanceToCluster_9  \
# 0                3.469159             3.385468             3.372909
# 1                3.245137             3.367481             3.325905
# 2                3.393217             3.496757             3.267370
# 3                4.062542             3.749640             3.513695
# 4                3.243731             2.807291             3.041460
# ...                   ...                  ...                  ...
# 7018             3.396204             1.796471             3.135504
# 7019             3.382982             1.446705             2.931037
# 7020             3.464392             2.009119             2.838596
# 7021             3.410394             1.041639             3.433294
# 7022             3.604872             2.031432             3.298113
#
#       DistanceToCluster_10  DistanceToCluster_11  DistanceToCluster_12  \
# 0                 1.816690              2.832223              3.440214
# 1                 1.412822              2.551059              2.976881
# 2                 1.711374              2.882332              2.967289
# 3                 2.460979              3.374777              3.714448
# 4                 2.135139              2.148691              2.646893
# ...                    ...                   ...                   ...
# 7018              3.019360              2.332833              3.050195
# 7019              3.031124              2.232547              3.196416
# 7020              3.278171              2.447167              3.156171
# 7021              3.303019              2.313352              3.216583
# 7022              3.263304              2.674701              3.243445
#
#       DistanceToCluster_13  DistanceToCluster_14
# 0                 1.947251              3.663139
# 1                 2.198815              3.466526
# 2                 1.818425              3.449917
# 3                 2.436172              3.156982
# 4                 1.471153              3.167368
# ...                    ...                   ...
# 7018              2.999064              2.132597
# 7019              2.962024              1.945804
# 7020              3.183305              2.389618
# 7021              3.193787              1.779254
# 7022              3.308293              2.200465
#
# [7023 rows x 18 columns]

# %%
### Очищаем память чтобы все влезло

model.cpu()

del model
del tokenizer

del dataset
del loader

del embeddings
del centered
del pca
del pca_decomp

# %%
import gc

gc.collect()
# Out:
# 67

# %%
posts_info.to_sql(
   "posts_info_features_dl",
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@postgres.lab.karpov.courses:6432/startml",
    schema="public",
    if_exists='replace'
)
# Out:
# 23

# %% [markdown]
# ## Теперь приступаем к обработке действий

# %%
### Попробуем забрать 9 миллионов, сразу очистим и оставим только view


feed_data = pd.read_sql(
    """
    SELECT
        cast(extract(hour from timestamp) as int) as hour,
        cast(extract(month from timestamp) as int) as month,
        post_id,
        gender,
        age,
        country,
        city,
        exp_group,
        os,
        source,
        target
    FROM public.feed_data JOIN public.user_data ON public.feed_data.user_id = public.user_data.user_id
    WHERE action = 'view'
    LIMIT 9000000
    """,
    con=connection
)

feed_data.head()
# Out:
#    hour  month  post_id  gender  age country    city  exp_group   os source  \
# 0    12     11     2622       1   17  Russia  Bratsk          4  iOS    ads
# 1    12     11     6773       1   17  Russia  Bratsk          4  iOS    ads
# 2    12     11     4056       1   17  Russia  Bratsk          4  iOS    ads
# 3    12     11     4806       1   17  Russia  Bratsk          4  iOS    ads
# 4    12     11     3145       1   17  Russia  Bratsk          4  iOS    ads
#
#    target
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0

# %%
from catboost import CatBoostClassifier, Pool
from tqdm import tqdm


object_cols = [
    'topic', 'TextCluster', 'gender', 'country',
    'city', 'exp_group', 'hour', 'month',
    'os', 'source'
]

catboost = CatBoostClassifier(
    iterations=200,
    learning_rate=1,
    depth=2,
    random_seed=12345612,
    thread_count=-1,
    task_type="GPU"
)

feed_data = pd.merge(
    feed_data,
    posts_info,
    on='post_id',
    how='left'
)

feed_data.drop(['post_id'], axis=1, inplace=True)

catboost.fit(X=feed_data.drop(['target'], axis=1), y=feed_data['target'], cat_features=object_cols)

catboost.save_model(
    'catboost_model_with_embedings.cbm',
    format="cbm"                  
)
# Out:
# 0:	learn: 0.3628461	total: 1.84s	remaining: 6m 5s
# 1:	learn: 0.3555639	total: 2.05s	remaining: 3m 22s
# 2:	learn: 0.3547324	total: 2.2s	remaining: 2m 24s
# 3:	learn: 0.3542446	total: 2.4s	remaining: 1m 57s
# 4:	learn: 0.3536791	total: 2.61s	remaining: 1m 41s
# 5:	learn: 0.3530154	total: 2.77s	remaining: 1m 29s
# 6:	learn: 0.3528464	total: 2.97s	remaining: 1m 22s
# 7:	learn: 0.3526629	total: 3.14s	remaining: 1m 15s
# 8:	learn: 0.3525565	total: 3.3s	remaining: 1m 10s
# 9:	learn: 0.3524670	total: 3.46s	remaining: 1m 5s
# 10:	learn: 0.3519275	total: 3.62s	remaining: 1m 2s
# 11:	learn: 0.3518803	total: 3.87s	remaining: 1m
# 12:	learn: 0.3516301	total: 4.04s	remaining: 58s
# 13:	learn: 0.3515474	total: 4.21s	remaining: 55.9s
# 14:	learn: 0.3513961	total: 4.49s	remaining: 55.3s
# 15:	learn: 0.3513300	total: 4.64s	remaining: 53.3s
# 16:	learn: 0.3507799	total: 4.79s	remaining: 51.6s
# 17:	learn: 0.3502944	total: 4.95s	remaining: 50s
# 18:	learn: 0.3499932	total: 5.13s	remaining: 48.8s
# 19:	learn: 0.3496089	total: 5.28s	remaining: 47.5s
# 20:	learn: 0.3495375	total: 5.44s	remaining: 46.4s
# 21:	learn: 0.3494484	total: 5.6s	remaining: 45.3s
# 22:	learn: 0.3494164	total: 5.79s	remaining: 44.6s
# 23:	learn: 0.3488308	total: 5.95s	remaining: 43.6s
# 24:	learn: 0.3487878	total: 6.1s	remaining: 42.7s
# 25:	learn: 0.3487308	total: 6.25s	remaining: 41.8s
# 26:	learn: 0.3487036	total: 6.4s	remaining: 41s
# 27:	learn: 0.3486373	total: 6.61s	remaining: 40.6s
# 28:	learn: 0.3485436	total: 6.77s	remaining: 39.9s
# 29:	learn: 0.3485152	total: 6.92s	remaining: 39.2s
# 30:	learn: 0.3484997	total: 7.12s	remaining: 38.8s
# 31:	learn: 0.3484634	total: 7.28s	remaining: 38.2s
# 32:	learn: 0.3484287	total: 7.43s	remaining: 37.6s
# 33:	learn: 0.3483851	total: 7.59s	remaining: 37.1s
# 34:	learn: 0.3483657	total: 7.75s	remaining: 36.5s
# 35:	learn: 0.3483469	total: 7.9s	remaining: 36s
# 36:	learn: 0.3482843	total: 8.15s	remaining: 35.9s
# 37:	learn: 0.3482739	total: 8.32s	remaining: 35.5s
# 38:	learn: 0.3481875	total: 8.47s	remaining: 35s
# 39:	learn: 0.3481690	total: 8.63s	remaining: 34.5s
# 40:	learn: 0.3481595	total: 8.85s	remaining: 34.3s
# 41:	learn: 0.3481244	total: 9.01s	remaining: 33.9s
# 42:	learn: 0.3479593	total: 9.17s	remaining: 33.5s
# 43:	learn: 0.3478267	total: 9.33s	remaining: 33.1s
# 44:	learn: 0.3478177	total: 9.49s	remaining: 32.7s
# 45:	learn: 0.3478070	total: 9.64s	remaining: 32.3s
# 46:	learn: 0.3477964	total: 9.8s	remaining: 31.9s
# 47:	learn: 0.3477842	total: 9.96s	remaining: 31.5s
# 48:	learn: 0.3477624	total: 10.1s	remaining: 31.2s
# 49:	learn: 0.3477553	total: 10.3s	remaining: 30.8s
# 50:	learn: 0.3476875	total: 10.4s	remaining: 30.4s
# 51:	learn: 0.3476764	total: 10.6s	remaining: 30.1s
# 52:	learn: 0.3476620	total: 10.7s	remaining: 29.8s
# 53:	learn: 0.3476453	total: 10.9s	remaining: 29.4s
# 54:	learn: 0.3476339	total: 11s	remaining: 29.1s
# 55:	learn: 0.3476120	total: 11.3s	remaining: 28.9s
# 56:	learn: 0.3475639	total: 11.4s	remaining: 28.6s
# 57:	learn: 0.3475419	total: 11.6s	remaining: 28.3s
# 58:	learn: 0.3475228	total: 11.7s	remaining: 28s
# 59:	learn: 0.3474790	total: 11.9s	remaining: 27.8s
# 60:	learn: 0.3474704	total: 12.1s	remaining: 27.5s
# 61:	learn: 0.3474509	total: 12.2s	remaining: 27.2s
# 62:	learn: 0.3474428	total: 12.4s	remaining: 27.1s
# 63:	learn: 0.3474171	total: 12.6s	remaining: 26.8s
# 64:	learn: 0.3474058	total: 12.8s	remaining: 26.5s
# 65:	learn: 0.3474027	total: 13s	remaining: 26.4s
# 66:	learn: 0.3473801	total: 13.2s	remaining: 26.1s
# 67:	learn: 0.3473656	total: 13.3s	remaining: 25.9s
# 68:	learn: 0.3473605	total: 13.5s	remaining: 25.6s
# 69:	learn: 0.3473297	total: 13.6s	remaining: 25.3s
# 70:	learn: 0.3473247	total: 13.8s	remaining: 25s
# 71:	learn: 0.3473168	total: 13.9s	remaining: 24.8s
# 72:	learn: 0.3473043	total: 14.1s	remaining: 24.5s
# 73:	learn: 0.3472916	total: 14.2s	remaining: 24.3s
# 74:	learn: 0.3472720	total: 14.4s	remaining: 24s
# 75:	learn: 0.3472514	total: 14.6s	remaining: 23.8s
# 76:	learn: 0.3472442	total: 14.7s	remaining: 23.5s
# 77:	learn: 0.3472412	total: 14.9s	remaining: 23.3s
# 78:	learn: 0.3472396	total: 15.1s	remaining: 23.1s
# 79:	learn: 0.3472279	total: 15.2s	remaining: 22.8s
# 80:	learn: 0.3472046	total: 15.4s	remaining: 22.6s
# 81:	learn: 0.3471979	total: 15.5s	remaining: 22.4s
# 82:	learn: 0.3471926	total: 15.7s	remaining: 22.1s
# 83:	learn: 0.3471818	total: 15.9s	remaining: 21.9s
# 84:	learn: 0.3471684	total: 16s	remaining: 21.7s
# 85:	learn: 0.3471613	total: 16.2s	remaining: 21.5s
# 86:	learn: 0.3471532	total: 16.4s	remaining: 21.2s
# 87:	learn: 0.3471449	total: 16.5s	remaining: 21s
# 88:	learn: 0.3471183	total: 16.8s	remaining: 20.9s
# 89:	learn: 0.3470989	total: 17s	remaining: 20.8s
# 90:	learn: 0.3470900	total: 17.2s	remaining: 20.6s
# 91:	learn: 0.3470789	total: 17.3s	remaining: 20.3s
# 92:	learn: 0.3470656	total: 17.5s	remaining: 20.1s
# 93:	learn: 0.3470642	total: 17.6s	remaining: 19.9s
# 94:	learn: 0.3470600	total: 17.8s	remaining: 19.7s
# 95:	learn: 0.3470553	total: 17.9s	remaining: 19.4s
# 96:	learn: 0.3470291	total: 18.1s	remaining: 19.2s
# 97:	learn: 0.3470243	total: 18.3s	remaining: 19s
# 98:	learn: 0.3470010	total: 18.4s	remaining: 18.8s
# 99:	learn: 0.3469969	total: 18.6s	remaining: 18.6s
# 100:	learn: 0.3469764	total: 18.7s	remaining: 18.4s
# 101:	learn: 0.3469690	total: 19s	remaining: 18.2s
# 102:	learn: 0.3469614	total: 19.1s	remaining: 18s
# 103:	learn: 0.3469505	total: 19.3s	remaining: 17.8s
# 104:	learn: 0.3469477	total: 19.4s	remaining: 17.6s
# 105:	learn: 0.3469250	total: 19.6s	remaining: 17.4s
# 106:	learn: 0.3469219	total: 19.7s	remaining: 17.2s
# 107:	learn: 0.3469173	total: 19.9s	remaining: 16.9s
# 108:	learn: 0.3469079	total: 20.1s	remaining: 16.7s
# 109:	learn: 0.3469055	total: 20.2s	remaining: 16.5s
# 110:	learn: 0.3468961	total: 20.4s	remaining: 16.3s
# 111:	learn: 0.3468763	total: 20.5s	remaining: 16.1s
# 112:	learn: 0.3468563	total: 20.7s	remaining: 15.9s
# 113:	learn: 0.3468523	total: 20.9s	remaining: 15.7s
# 114:	learn: 0.3468504	total: 21.1s	remaining: 15.6s
# 115:	learn: 0.3468436	total: 21.2s	remaining: 15.4s
# 116:	learn: 0.3468392	total: 21.4s	remaining: 15.2s
# 117:	learn: 0.3468299	total: 21.5s	remaining: 15s
# 118:	learn: 0.3468252	total: 21.7s	remaining: 14.8s
# 119:	learn: 0.3468217	total: 21.8s	remaining: 14.5s
# 120:	learn: 0.3468145	total: 22s	remaining: 14.4s
# 121:	learn: 0.3468081	total: 22.3s	remaining: 14.2s
# 122:	learn: 0.3468044	total: 22.5s	remaining: 14.1s
# 123:	learn: 0.3467989	total: 22.6s	remaining: 13.9s
# 124:	learn: 0.3467716	total: 22.9s	remaining: 13.7s
# 125:	learn: 0.3467697	total: 23.1s	remaining: 13.6s
# 126:	learn: 0.3467596	total: 23.2s	remaining: 13.4s
# 127:	learn: 0.3467551	total: 23.4s	remaining: 13.2s
# 128:	learn: 0.3467491	total: 23.5s	remaining: 13s
# 129:	learn: 0.3467428	total: 23.7s	remaining: 12.8s
# 130:	learn: 0.3467328	total: 24s	remaining: 12.6s
# 131:	learn: 0.3467284	total: 24.1s	remaining: 12.4s
# 132:	learn: 0.3467216	total: 24.3s	remaining: 12.2s
# 133:	learn: 0.3467206	total: 24.5s	remaining: 12.1s
# 134:	learn: 0.3467129	total: 24.6s	remaining: 11.9s
# 135:	learn: 0.3466955	total: 24.8s	remaining: 11.7s
# 136:	learn: 0.3466868	total: 25s	remaining: 11.5s
# 137:	learn: 0.3466798	total: 25.2s	remaining: 11.3s
# 138:	learn: 0.3466703	total: 25.3s	remaining: 11.1s
# 139:	learn: 0.3466584	total: 25.5s	remaining: 10.9s
# 140:	learn: 0.3466522	total: 25.6s	remaining: 10.7s
# 141:	learn: 0.3466443	total: 25.8s	remaining: 10.5s
# 142:	learn: 0.3466361	total: 25.9s	remaining: 10.3s
# 143:	learn: 0.3466293	total: 26.1s	remaining: 10.1s
# 144:	learn: 0.3466231	total: 26.3s	remaining: 9.96s
# 145:	learn: 0.3466189	total: 26.4s	remaining: 9.77s
# 146:	learn: 0.3466129	total: 26.6s	remaining: 9.58s
# 147:	learn: 0.3466084	total: 26.7s	remaining: 9.39s
# 148:	learn: 0.3465977	total: 26.9s	remaining: 9.21s
# 149:	learn: 0.3465920	total: 27.1s	remaining: 9.02s
# 150:	learn: 0.3465839	total: 27.2s	remaining: 8.83s
# 151:	learn: 0.3465812	total: 27.4s	remaining: 8.65s
# 152:	learn: 0.3465689	total: 27.5s	remaining: 8.46s
# 153:	learn: 0.3465549	total: 27.7s	remaining: 8.27s
# 154:	learn: 0.3465516	total: 27.9s	remaining: 8.09s
# 155:	learn: 0.3465408	total: 28s	remaining: 7.9s
# 156:	learn: 0.3465292	total: 28.2s	remaining: 7.72s
# 157:	learn: 0.3465189	total: 28.3s	remaining: 7.53s
# 158:	learn: 0.3465043	total: 28.5s	remaining: 7.34s
# 159:	learn: 0.3464965	total: 28.6s	remaining: 7.16s
# 160:	learn: 0.3464952	total: 28.8s	remaining: 6.97s
# 161:	learn: 0.3464828	total: 28.9s	remaining: 6.79s
# 162:	learn: 0.3464752	total: 29.1s	remaining: 6.61s
# 163:	learn: 0.3464710	total: 29.3s	remaining: 6.42s
# 164:	learn: 0.3464580	total: 29.4s	remaining: 6.24s
# 165:	learn: 0.3464523	total: 29.6s	remaining: 6.06s
# 166:	learn: 0.3464492	total: 29.7s	remaining: 5.88s
# 167:	learn: 0.3464437	total: 29.9s	remaining: 5.7s
# 168:	learn: 0.3464416	total: 30.1s	remaining: 5.52s
# 169:	learn: 0.3464372	total: 30.3s	remaining: 5.34s
# 170:	learn: 0.3464325	total: 30.4s	remaining: 5.16s
# 171:	learn: 0.3464270	total: 30.6s	remaining: 4.97s
# 172:	learn: 0.3464231	total: 30.7s	remaining: 4.79s
# 173:	learn: 0.3464184	total: 30.9s	remaining: 4.61s
# 174:	learn: 0.3464131	total: 31s	remaining: 4.43s
# 175:	learn: 0.3464072	total: 31.2s	remaining: 4.25s
# 176:	learn: 0.3464036	total: 31.3s	remaining: 4.07s
# 177:	learn: 0.3464000	total: 31.5s	remaining: 3.89s
# 178:	learn: 0.3463941	total: 31.7s	remaining: 3.71s
# 179:	learn: 0.3463924	total: 31.8s	remaining: 3.54s
# 180:	learn: 0.3463894	total: 32s	remaining: 3.36s
# 181:	learn: 0.3463868	total: 32.1s	remaining: 3.18s
# 182:	learn: 0.3463832	total: 32.3s	remaining: 3s
# 183:	learn: 0.3463649	total: 32.5s	remaining: 2.82s
# 184:	learn: 0.3463608	total: 32.6s	remaining: 2.64s
# 185:	learn: 0.3463584	total: 32.8s	remaining: 2.47s
# 186:	learn: 0.3463544	total: 32.9s	remaining: 2.29s
# 187:	learn: 0.3463107	total: 33.1s	remaining: 2.11s
# 188:	learn: 0.3463024	total: 33.2s	remaining: 1.93s
# 189:	learn: 0.3462965	total: 33.4s	remaining: 1.76s
# 190:	learn: 0.3462839	total: 33.5s	remaining: 1.58s
# 191:	learn: 0.3462777	total: 33.7s	remaining: 1.4s
# 192:	learn: 0.3462709	total: 33.9s	remaining: 1.23s
# 193:	learn: 0.3462660	total: 34s	remaining: 1.05s
# 194:	learn: 0.3462572	total: 34.2s	remaining: 876ms
# 195:	learn: 0.3462520	total: 34.3s	remaining: 701ms
# 196:	learn: 0.3462472	total: 34.5s	remaining: 525ms
# 197:	learn: 0.3462442	total: 34.7s	remaining: 350ms
# 198:	learn: 0.3462427	total: 34.8s	remaining: 175ms
# 199:	learn: 0.3462338	total: 35s	remaining: 0us
